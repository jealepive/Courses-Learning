# %%
# %pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import  cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img =cv2.imread("2020_4_16_20_57.png")
img_base = cv2.imread("base_image.png")

# Muestra imagen en ventana
cv2.imshow("Imagen",img - img_base)
cv2.imshow("Imagen2", img_base - img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img - img_base)
img.shape
# Out:
# (2000, 2000, 3)
